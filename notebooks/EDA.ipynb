# %% [markdown]
# ## Import Data

# %%
import numpy as np
import pandas as pd
import os

# %%
os.listdir('/Users/julienfestou/Desktop/Exports_BO/')
# Out:
# ['.DS_Store',
#  'residencies_list.csv',
#  'parcels_list.csv',
#  'members_list.csv',
#  'companies_list.csv']

# %%
path = '/Users/julienfestou/Desktop/Exports_BO/'
files = os.listdir(path)
del files[0]

# %%
files
# Out:
# ['residencies_list.csv',
#  'parcels_list.csv',
#  'members_list.csv',
#  'companies_list.csv']

# %%
df_res = pd.read_csv(path + files[0])
df_par = pd.read_csv(path + files[1])
df_cop = pd.read_csv(path + files[2])
df_syn = pd.read_csv(path + files[3])
# Out:
# /Users/julienfestou/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (5,13,14,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(f'Résidences : {df_res.shape}')
print(f'Lots : {df_par.shape}')
print(f'Copropriétaires : {df_cop.shape}')
print(f'Syndics : {df_syn.shape}')
# Out:
# Résidences : (6184, 12)
# Lots : (318100, 18)
# Copropriétaires : (179708, 13)
# Syndics : (134, 12)

# %% [markdown]
# ## Données résidences

# %%
df_res.head(3)
# Out:
#                                      id  Code                         Nom  \
# 0  0012cf58-0a61-11ec-8db6-062a5c615ffe   NaN     RESIDENCES LES ALIZES 2
# 1  001fe14b-9bd5-4ea5-ae1f-573733124d47    57                 CRISTALLINE
# 2  002e8a82-e20f-11ea-8db6-062a5c615ffe  1173  RESIDENCE LE PARC DAUPHINE
#
#               Adresse Adresse (complement) Code postal         Ville Pays  \
# 0           DAMPIERRE                  NaN       97190        Gosier   MQ
# 1  76 a 78 rue Promis                  NaN       33100      BORDEAUX  NaN
# 2    RUE DES LAURIERS                  NaN       94370  SUCY EN BRIE  NaN
#
#             Ajoutée le    Syndic / Client  Nb Lots  Nb Assemblées
# 0  2021-08-31 13:40:27           IMMO 971     62.0            0.0
# 1  2022-01-26 09:25:13  Atlantic Bordeaux     79.0            0.0
# 2  2020-08-19 11:27:44        syndic-immo     27.0            0.0

# %%
df_res['nb_res'] = 1.0

# %%
df_res_new = df_res.groupby(by=df_res['Syndic / Client']).sum()

# %%
df_res_new
# Out:
#                       Nb Lots  Nb Assemblées  nb_res
# Syndic / Client
#  Atelier Immobilier     256.0            1.0     1.0
# A2CIMMO                6466.0            0.0    66.0
# ACANTHE                  11.0           18.0     4.0
# ACANTYS IMMOBILIER        0.0            1.0     1.0
# ADL                   24419.0           10.0   222.0
# ...                       ...            ...     ...
# parcstestephe           135.0            1.0     1.0
# sai-immo                845.0            3.0    44.0
# syndic-immo           10033.0           17.0   152.0
# tarzania                  0.0            1.0     1.0
# test                      3.0            1.0     1.0
#
# [139 rows x 3 columns]

# %% [markdown]
# ## Données Lots

# %%
df_par.head(3)
# Out:
#                                      id   N° Code Résidence  \
# 0  003b08f9-b9a6-4dce-8a80-0442751dcd01  211           0161
# 1  004aebe8-8a89-49f4-81f8-26e35191499a  138            NaN
# 2  0077d335-c3bd-4677-835b-2f0a0713cfd8   06           0254
#
#              Nom Résidence Client / Syndic Bâtiment        Type de lot  \
# 0                 CARRIBEA        Groupimo      NaN  Parking extérieur
# 1             LES GOMMIERS           Modus      NaN  Parking extérieur
# 2  SDC 194 GENERAL LECLERC           IMMEA      NaN             Studio
#
#   Libellé Copro Raison sociale        Copro Nom       Copro Prénom  \
# 0     NaN                  NaN  DELBOS Philippe                NaN
# 1     NaN                  NaN          DEBRIT   Didier & Isabelle
# 2     NaN                  NaN           MONKAM            Florian
#
#           Copro Email Copro Téléphone Locataire Raison sociale Locataire Nom  \
# 0                 NaN             NaN                      NaN           NaN
# 1                 NaN             NaN                      NaN           NaN
# 2  monkam.f@gmail.com  06.50.37.59.92                      NaN           NaN
#
#   Locataire Prénom Locataire Email Locataire Téléphone
# 0              NaN             NaN                 NaN
# 1              NaN             NaN                 NaN
# 2              NaN             NaN                 NaN

# %%
liste_lots_principaux = [
        'Appartement',
        'appart+cave',
        'appartement_t2',
        'appartement_t3',
        'appartement_t4',
        'appartement_t5',
        'appartement_t6',
        'appartement_t7',
        'appart+cave',
        't2',
        't2 meuble',
        't3',
        't3 meuble',
        't3/4',
        't4',
        't4 meuble',
        't5',
        't5 meuble',
        't6',
        't7',
        't8',
        'dup',
        'dupl',
        'duple',
        'duplex',
        'appar',
        'appart',
        'apparte',
        'appartem',
        'apparteme',
        'appartemen',
        'appartement',
        'Local commercial',
        'comm',
        'comme',
        'commer',
        'commerc',
        'commerce',
        'local comm',
        'local commercial',
        'local_ccial',
        'aire de vente',
        'maga',
        'magas',
        'magasi',
        'magasin',
        'Maison',
        'mais',
        'maiso',
        'maison',
        'Studio',
        'cham',
        'chamb',
        'chambr',
        'chambre',
        'stud',
        'studi',
        'studio',
        't1',
        't1 bis',
        'pie',
        'piec',
        'piece',
        'Local professionnel',
        'bure',
        'burea',
        'bureau',
        'bureaux',
        'labo',
        'labor',
        'labora',
        'laborat',
        'laboratoire',
        'café',
        'cafe',
        'lave',
        'laver',
        'laveri',
        'laverie',
        'loca',
        'local',
        'atel',
        'ateli',
        'atelie',
        'atelier',
        'bur',
        'bure',
        'burea',
        'bureau'
        'Bien rural',
        'chale',
        'chalet',
        'Terrain',
        'terr',
        'terrain',
        'Immeuble',
        'immeuble',
        'batiment',
        'bâtiment',
        'bâtimen',
        'bâtime',
        'bâtim',
        'bât',
        'bât.']

# %%
df_par['nb_lots_principaux'] = df_par['Type de lot'].map(lambda x:1.0 if x in liste_lots_principaux else 0.0)

# %%
df_par_new = df_par.groupby(by=df_par['Client / Syndic']).sum()

# %%
df_par_new = df_par_new.sort_index()

# %%
df_par_new
# Out:
#                        nb_lots_principaux
# Client / Syndic
#  Atelier Immobilier                 103.0
# A2CIMMO                               0.0
# ACANTHE                              11.0
# ADL                                9992.0
# AG IDF - Abri Gestion              1368.0
# ...                                   ...
# immosQquare                         989.0
# parcstestephe                        45.0
# sai-immo                            415.0
# syndic-immo                        3910.0
# test                                  3.0
#
# [125 rows x 1 columns]

# %% [markdown]
# ## Données copropriétaires

# %%
df_cop.head()
# Out:
#                                      id       Raison sociale Prénom  \
# 0  00017a0c-bd21-11ea-9c15-065464eae358                  NaN    NaN
# 1  0001f9b2-f8c1-4fc6-8b26-ce5d835a71d5                  NaN  Alain
# 2  00023180-fe8b-4ac5-99d9-cdc1b2e966c9  CE PROPHARM AVENTIS    NaN
# 3  00027326-e214-11ea-8db6-062a5c615ffe         LORRE CLAUDE    NaN
# 4  0002ae39-bd1e-11ea-9c15-065464eae358                  NaN    NaN
#
#                    Nom                        Email  Téléphone  \
# 0      IC DISTRIBUTION   m.vidal@ic-distribution.fr        NaN
# 1            MARGUERIT  alain.marguerit@laposte.net  626268069
# 2                  NaN   aicha.kennouche@sanofi.com  145188347
# 3                  NaN                          NaN        NaN
# 4  BERTRAND Christophe                          NaN        NaN
#
#              Ajouté le                   Adresse Adresse (complement)  \
# 0  2020-07-03 11:33:21  125 Rue de la Sarriette                   NaN
# 1  2022-02-01 11:07:24  19 ALLEE DU CLOS D'AVENA                  NaN
# 2  2022-02-17 10:48:45       180 rue Jean Jaures        BP 40 – CEDEX
# 3  2020-08-19 12:03:31         9 RUE DES NOBLETS                  NaN
# 4  2020-07-03 11:11:53           37 Rue de Lagny                  NaN
#
#   Code postal           Ville Pays                     Syndic / Client
# 0       34130     SAINT-AUNES  NaN                    Alter Immobilier
# 1       31320  VIGOULET AUZIL  NaN                    Atlantic Lacanau
# 2       94702  MAISONS ALFORT  NaN  Atlantic Saint-Gilles-Croix-de-Vie
# 3       91770     SAINT VRAIN  NaN                         syndic-immo
# 4       77700          SERRIS  NaN                    Alter Immobilier

# %%
df_cop['nb_copros'] = 1.0

# %%
df_cop['nb_emails'] = df_cop['Email'].map(lambda x:1.0 if pd.notna(x) else 0.0)

# %%
df_cop
# Out:
#                                           id       Raison sociale   Prénom  \
# 0       00017a0c-bd21-11ea-9c15-065464eae358                  NaN      NaN
# 1       0001f9b2-f8c1-4fc6-8b26-ce5d835a71d5                  NaN    Alain
# 2       00023180-fe8b-4ac5-99d9-cdc1b2e966c9  CE PROPHARM AVENTIS      NaN
# 3       00027326-e214-11ea-8db6-062a5c615ffe         LORRE CLAUDE      NaN
# 4       0002ae39-bd1e-11ea-9c15-065464eae358                  NaN      NaN
# ...                                      ...                  ...      ...
# 179703  fffd479e-70c4-4f23-b5ff-2c746d535d2a                  NaN    Herve
# 179704  fffd775b-6193-4340-a4a6-8349839f7d6e                  NaN  Bernard
# 179705  ffff61cd-6970-11ec-8db6-062a5c615ffe                  NaN      NaN
# 179706  ffff88b8-aa2f-11ea-9c15-065464eae358               VALERY  BASTIEN
# 179707  ffffa582-7a07-11ec-8db6-062a5c615ffe                  NaN      NaN
#
#                                   Nom                        Email  \
# 0                     IC DISTRIBUTION   m.vidal@ic-distribution.fr
# 1                           MARGUERIT  alain.marguerit@laposte.net
# 2                                 NaN   aicha.kennouche@sanofi.com
# 3                                 NaN                          NaN
# 4                 BERTRAND Christophe                          NaN
# ...                               ...                          ...
# 179703                        GEANDEL        hervegeandel@yahoo.fr
# 179704                           MACE       bernard-mace@orange.fr
# 179705                  LANGLOIS Omog           bonieck_g@yahoo.fr
# 179706                            NaN  bastien.valery@aliceadsl.fr
# 179707  GEROMEGNACE ou GHOCANE Marius                          NaN
#
#          Téléphone            Ajouté le                             Adresse  \
# 0              NaN  2020-07-03 11:33:21            125 Rue de la Sarriette
# 1        626268069  2022-02-01 11:07:24            19 ALLEE DU CLOS D'AVENA
# 2        145188347  2022-02-17 10:48:45                 180 rue Jean Jaures
# 3              NaN  2020-08-19 12:03:31                   9 RUE DES NOBLETS
# 4              NaN  2020-07-03 11:11:53                     37 Rue de Lagny
# ...            ...                  ...                                 ...
# 179703   231641470  2022-02-17 10:48:31            2 IMPASSE DE LA TERRASSE
# 179704   299661216  2022-01-27 16:08:26                4 rue Le Chene Droit
# 179705   625068196  2021-12-30 13:04:19  2 RUE DU PRESIDENT GEORGE POMPIDOU
# 179706  0658873318  2020-06-09 09:02:52             635 RueFrédéric Mistral
# 179707         NaN  2022-01-20 15:45:31             Lot 15 l'Oree de Perrin
#
#        Adresse (complement) Code postal                  Ville    Pays  \
# 0                       NaN       34130            SAINT-AUNES     NaN
# 1                       NaN       31320         VIGOULET AUZIL     NaN
# 2             BP 40 – CEDEX       94702         MAISONS ALFORT     NaN
# 3                       NaN       91770            SAINT VRAIN     NaN
# 4                       NaN       77700                 SERRIS     NaN
# ...                     ...         ...                    ...     ...
# 179703                  NaN       31500               TOULOUSE     NaN
# 179704                  NaN       35520                MELESSE     NaN
# 179705                  NaN       93440                  Dugny      FR
# 179706                  NaN       07000  ST JULIEN EN ST ALBAN  FRANCE
# 179707                  NaN       97111          Morne-à-l'Eau      FR
#
#                            Syndic / Client  nb_copros  nb_emails
# 0                         Alter Immobilier        1.0        1.0
# 1                         Atlantic Lacanau        1.0        1.0
# 2       Atlantic Saint-Gilles-Croix-de-Vie        1.0        1.0
# 3                              syndic-immo        1.0        0.0
# 4                         Alter Immobilier        1.0        0.0
# ...                                    ...        ...        ...
# 179703  Atlantic Saint-Gilles-Croix-de-Vie        1.0        1.0
# 179704              Atlantic SYNDIC Rennes        1.0        1.0
# 179705               Cabinet Eleos Conseil        1.0        1.0
# 179706                                 CGS        1.0        1.0
# 179707                 AGENCE IMMO CONSEIL        1.0        0.0
#
# [179708 rows x 15 columns]

# %%
df_cop_new = df_cop.groupby(by=df_cop['Syndic / Client']).sum()

# %%
df_cop_new
# Out:
#                       nb_copros  nb_emails
# Syndic / Client
#  Atelier Immobilier       114.0       64.0
# 9863940 Canada Inc          1.0        1.0
# A2CIMMO                  2714.0     1806.0
# ACANTHE                     8.0        8.0
# ACANTYS IMMOBILIER          1.0        1.0
# ...                         ...        ...
# parcstestephe              47.0        9.0
# sai-immo                  856.0      645.0
# syndic-immo              6019.0     2671.0
# tarzania                    1.0        1.0
# test                        7.0        2.0
#
# [154 rows x 2 columns]

# %%
df_cop_new.nb_copros.sum()
# Out:
# 177555.0

# %% [markdown]
# ## Données Syndics

# %%
df_syn.head()
# Out:
#                                      id                 Nom  \
# 0  04590ff4-9f4b-11ea-9c15-065464eae358              Syndic
# 1  04ece22a-001c-11eb-8db6-062a5c615ffe  9863940 Canada Inc
# 2  0edf99f6-a96a-11ea-9c15-065464eae358       Rohan Néogère
# 3  0f446b36-7283-11eb-8db6-062a5c615ffe    ASL Victoria-CFH
# 4  119e7ec9-a98e-11ea-9c15-065464eae358               IMMEA
#
#                                        Adresse Adresse (complement)  \
# 0                                  Rue du port                  NaN
# 1  3-117 rue Principale S, Lebel-sur-Quévillon                  NaN
# 2  7 rue Anatole France 92300 LEVALLOIS PERRET                  NaN
# 3                                          NaN                  NaN
# 4                                 109 bd Dalby                  NaN
#
#   Code postal      Ville Pays            Ajouté le  \
# 0       50400  Granville   FR  2020-05-26 12:18:33
# 1         NaN        NaN  NaN  2020-09-26 17:16:30
# 2         NaN        NaN  NaN  2020-06-08 09:25:56
# 3         NaN        NaN  NaN  2021-02-19 07:21:18
# 4       44000     Nantes   FR  2020-06-08 13:43:43
#
#                  Adresse email facturation  Nb Résidences  Nb Assemblées  \
# 0                  syment.agdemo@gmail.com           23.0          657.0
# 1  9863940@samuelbisson660.onmicrosoft.com            0.0            0.0
# 2                  neogeresyment@gmail.com            1.0            1.0
# 3                                      NaN            2.0            3.0
# 4                    immeasyment@gmail.com           66.0           48.0
#
#    Client Dometech
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_syn['clients_dometech'] = df_syn['Client Dometech'].map(lambda x:1.0 if pd.notna(x) else 0.0)

# %%
df_syn.head()
# Out:
#                                      id                 Nom  \
# 0  04590ff4-9f4b-11ea-9c15-065464eae358              Syndic
# 1  04ece22a-001c-11eb-8db6-062a5c615ffe  9863940 Canada Inc
# 2  0edf99f6-a96a-11ea-9c15-065464eae358       Rohan Néogère
# 3  0f446b36-7283-11eb-8db6-062a5c615ffe    ASL Victoria-CFH
# 4  119e7ec9-a98e-11ea-9c15-065464eae358               IMMEA
#
#                                        Adresse Adresse (complement)  \
# 0                                  Rue du port                  NaN
# 1  3-117 rue Principale S, Lebel-sur-Quévillon                  NaN
# 2  7 rue Anatole France 92300 LEVALLOIS PERRET                  NaN
# 3                                          NaN                  NaN
# 4                                 109 bd Dalby                  NaN
#
#   Code postal      Ville Pays            Ajouté le  \
# 0       50400  Granville   FR  2020-05-26 12:18:33
# 1         NaN        NaN  NaN  2020-09-26 17:16:30
# 2         NaN        NaN  NaN  2020-06-08 09:25:56
# 3         NaN        NaN  NaN  2021-02-19 07:21:18
# 4       44000     Nantes   FR  2020-06-08 13:43:43
#
#                  Adresse email facturation  Nb Résidences  Nb Assemblées  \
# 0                  syment.agdemo@gmail.com           23.0          657.0
# 1  9863940@samuelbisson660.onmicrosoft.com            0.0            0.0
# 2                  neogeresyment@gmail.com            1.0            1.0
# 3                                      NaN            2.0            3.0
# 4                    immeasyment@gmail.com           66.0           48.0
#
#    Client Dometech  clients_dometech
# 0              NaN               0.0
# 1              NaN               0.0
# 2              NaN               0.0
# 3              NaN               0.0
# 4              NaN               0.0

# %%
df_syn_new = df_syn.groupby(by=df_syn['Nom']).sum()

# %%
df_syn_new = df_syn_new.drop(columns=['Nb Résidences', 'Nb Assemblées', 'Client Dometech'])

# %%
df_syn_new
# Out:
#                       clients_dometech
# Nom
#  Atelier Immobilier                0.0
# 9863940 Canada Inc                 0.0
# A2CIMMO                            0.0
# ACANTHE                            0.0
# ACANTYS IMMOBILIER                 0.0
# ...                                ...
# parcstestephe                      0.0
# sai-immo                           0.0
# syndic-immo                        0.0
# tarzania                           0.0
# test                               0.0
#
# [133 rows x 1 columns]

# %%
df = df_cop_new.join(df_par_new)

# %%
df = df.join(df_syn_new)

# %%
df = df.join(df_res_new)

# %%
df
# Out:
#                       nb_copros  nb_emails  nb_lots_principaux  \
# Syndic / Client
#  Atelier Immobilier       114.0       64.0               103.0
# 9863940 Canada Inc          1.0        1.0                 NaN
# A2CIMMO                  2714.0     1806.0                 0.0
# ACANTHE                     8.0        8.0                11.0
# ACANTYS IMMOBILIER          1.0        1.0                 NaN
# ...                         ...        ...                 ...
# parcstestephe              47.0        9.0                45.0
# sai-immo                  856.0      645.0               415.0
# syndic-immo              6019.0     2671.0              3910.0
# tarzania                    1.0        1.0                 NaN
# test                        7.0        2.0                 3.0
#
#                       clients_dometech  Nb Lots  Nb Assemblées  nb_res
# Syndic / Client
#  Atelier Immobilier                0.0    256.0            1.0     1.0
# 9863940 Canada Inc                 0.0      NaN            NaN     NaN
# A2CIMMO                            0.0   6466.0            0.0    66.0
# ACANTHE                            0.0     11.0           18.0     4.0
# ACANTYS IMMOBILIER                 0.0      0.0            1.0     1.0
# ...                                ...      ...            ...     ...
# parcstestephe                      0.0    135.0            1.0     1.0
# sai-immo                           0.0    845.0            3.0    44.0
# syndic-immo                        0.0  10033.0           17.0   152.0
# tarzania                           0.0      0.0            1.0     1.0
# test                               0.0      3.0            1.0     1.0
#
# [154 rows x 7 columns]

# %%
cols = ['nb_copros','nb_res', 'Nb Lots', 'nb_lots_principaux', 'nb_emails', 'Nb Assemblées', 'clients_dometech']

# %%
df = df[cols]

# %%
df = df.rename(columns={'Nb Lots':'nb_lots', 'Nb Assemblées':'nb_assemblées'})

# %%
df.index
# Out:
# Index([' Atelier Immobilier ', '9863940 Canada Inc', 'A2CIMMO', 'ACANTHE',
#        'ACANTYS IMMOBILIER', 'ADL', 'AG IDF - Abri Gestion',
#        'AGENCE IMMO CONSEIL', 'AGESTYS', 'AH IMMOBILIER',
#        ...
#        'eguimos', 'guy hoquet', 'iPro', 'immosQquare',
#        'limpide immobilier duriez', 'parcstestephe', 'sai-immo', 'syndic-immo',
#        'tarzania', 'test'],
#       dtype='object', name='Syndic / Client', length=154)

# %%
syn_suppr = [
    '9863940 Canada Inc',
    'AJP Syndic Saint Malo',
    'AKAWAN',
    'ASL Victoria-CFH',
    'Acti Syndic',
    'Alteal',
    'BR',
    'CABINET DUCOS IMMOBILIER',
    'CHARO',
    'CIS Immobilier',
    'CS Pershing',
    'CS desaix',
    'Cabinet J. SOTTO',
    'Century 21',
    'Conseil Syndical',
    'Démo - Seine Gestion & Batim et Fils',
    'FONTENOY IMMOBILIER MARTINIQUE',
    'Folliot',
    'Gerancimo Amiens',
    'Guillemot',
    'Hôpitaux Facultés Immobilier',
    'IMMOTEP',
    'Immobilière du Chateau',
    'Imvesters',
    'Inowai',
    'Keredes Test',
    "L'Orée Verte Immobilier",
    'LES TERRASSES DE DORNACH',
    'Les allées de Balma',
    'MP INVESTISSEMENT',
    'Michaël AMADO',
    'PBBG',
    'RESIDENCES ET PATRIMOINE ',
    'ROSIER MIP',
    'Rohan Néogère',
    'Rosati',
    'SCCDP',
    'SCI KADIM',
    'SCP BLANKENBERG JOBARD',
    'SECRI GESTION',
    'SLPCVM',
    'SOGIRE',
    'SYNDIC COOPERATIF PARADISE VILLAS',
    'Sacclo',
    'SdC Havre du fleuve phase 1',
    'Seguinot Christophe',
    'Sponsorize Sàrl',
    'Syment Demo',
    'Syment Demo EN',
    'Syment Evol',
    'Syment Syndic',
    'Syndic',
    'Syndic de la mort',
    'Synergestion',
    'Twinsys',
    'VACHERAND IMMOBILIER',
    'Vacherand Immobilier',
    'Weiss Asset Management SARL',
    'Y.S. Immobilier',
    'armen',
    'cabinet cadoret immobilier',
    'guy hoquet',
    'limpide immobilier duriez',
    'parcstestephe',
    'tarzania',
    'test',
    'eguimos',
    'SEINE GESTION',
    'Immobilière Buecher ',
    'Cagim sogedim',
    'BATIM & FILS - COPROPRIÉTÉS',
    'Artesia',
    'Artésia'
]

# %%
df = df.drop(syn_suppr)

# %%
df
# Out:
#                       nb_copros  nb_res  nb_lots  nb_lots_principaux  \
# Syndic / Client
#  Atelier Immobilier       114.0     1.0    256.0               103.0
# A2CIMMO                  2714.0    66.0   6466.0                 0.0
# ACANTHE                     8.0     4.0     11.0                11.0
# ACANTYS IMMOBILIER          1.0     1.0      0.0                 NaN
# ADL                      9570.0   222.0  24419.0              9992.0
# ...                         ...     ...      ...                 ...
# Thierry Immobilier       1392.0    24.0   3507.0              1668.0
# iPro                       22.0     1.0     15.0                15.0
# immosQquare               653.0    50.0   2215.0               989.0
# sai-immo                  856.0    44.0    845.0               415.0
# syndic-immo              6019.0   152.0  10033.0              3910.0
#
#                       nb_emails  nb_assemblées  clients_dometech
# Syndic / Client
#  Atelier Immobilier        64.0            1.0               0.0
# A2CIMMO                  1806.0            0.0               0.0
# ACANTHE                     8.0           18.0               0.0
# ACANTYS IMMOBILIER          1.0            1.0               0.0
# ADL                      7758.0           10.0               0.0
# ...                         ...            ...               ...
# Thierry Immobilier       1333.0           24.0               0.0
# iPro                       17.0            3.0               0.0
# immosQquare               584.0           12.0               0.0
# sai-immo                  645.0            3.0               0.0
# syndic-immo              2671.0           17.0               0.0
#
# [81 rows x 7 columns]

# %%
df['dometech'] = df['clients_dometech'].map(lambda x:'Oui' if x == 1 else 'Non')

# %%
total = df.sum()
total.name = 'Total'
df = df.append(total.transpose())

# %%
df
# Out:
#                       nb_copros  nb_res   nb_lots  nb_lots_principaux  \
# Syndic / Client
#  Atelier Immobilier       114.0     1.0     256.0               103.0
# A2CIMMO                  2714.0    66.0    6466.0                 0.0
# ACANTHE                     8.0     4.0      11.0                11.0
# ACANTYS IMMOBILIER          1.0     1.0       0.0                 NaN
# ADL                      9570.0   222.0   24419.0              9992.0
# ...                         ...     ...       ...                 ...
# iPro                       22.0     1.0      15.0                15.0
# immosQquare               653.0    50.0    2215.0               989.0
# sai-immo                  856.0    44.0     845.0               415.0
# syndic-immo              6019.0   152.0   10033.0              3910.0
# Total                  163136.0  5578.0  303797.0            120775.0
#
#                       nb_emails  nb_assemblées  clients_dometech  \
# Syndic / Client
#  Atelier Immobilier        64.0            1.0               0.0
# A2CIMMO                  1806.0            0.0               0.0
# ACANTHE                     8.0           18.0               0.0
# ACANTYS IMMOBILIER          1.0            1.0               0.0
# ADL                      7758.0           10.0               0.0
# ...                         ...            ...               ...
# iPro                       17.0            3.0               0.0
# immosQquare               584.0           12.0               0.0
# sai-immo                  645.0            3.0               0.0
# syndic-immo              2671.0           17.0               0.0
# Total                  120249.0         1781.0               0.0
#
#                                                                dometech
# Syndic / Client
#  Atelier Immobilier                                                 Non
# A2CIMMO                                                             Non
# ACANTHE                                                             Non
# ACANTYS IMMOBILIER                                                  Non
# ADL                                                                 Non
# ...                                                                 ...
# iPro                                                                Non
# immosQquare                                                         Non
# sai-immo                                                            Non
# syndic-immo                                                         Non
# Total                 NonNonNonNonNonNonNonNonNonNonNonNonNonNonNonN...
#
# [82 rows x 8 columns]

# %%
df['dometech'].values[81] = ''

# %%
df
# Out:
#                       nb_copros  nb_res   nb_lots  nb_lots_principaux  \
# Syndic / Client
#  Atelier Immobilier       114.0     1.0     256.0               103.0
# A2CIMMO                  2714.0    66.0    6466.0                 0.0
# ACANTHE                     8.0     4.0      11.0                11.0
# ACANTYS IMMOBILIER          1.0     1.0       0.0                 NaN
# ADL                      9570.0   222.0   24419.0              9992.0
# ...                         ...     ...       ...                 ...
# iPro                       22.0     1.0      15.0                15.0
# immosQquare               653.0    50.0    2215.0               989.0
# sai-immo                  856.0    44.0     845.0               415.0
# syndic-immo              6019.0   152.0   10033.0              3910.0
# Total                  163136.0  5578.0  303797.0            120775.0
#
#                       nb_emails  nb_assemblées  clients_dometech dometech
# Syndic / Client
#  Atelier Immobilier        64.0            1.0               0.0      Non
# A2CIMMO                  1806.0            0.0               0.0      Non
# ACANTHE                     8.0           18.0               0.0      Non
# ACANTYS IMMOBILIER          1.0            1.0               0.0      Non
# ADL                      7758.0           10.0               0.0      Non
# ...                         ...            ...               ...      ...
# iPro                       17.0            3.0               0.0      Non
# immosQquare               584.0           12.0               0.0      Non
# sai-immo                  645.0            3.0               0.0      Non
# syndic-immo              2671.0           17.0               0.0      Non
# Total                  120249.0         1781.0               0.0
#
# [82 rows x 8 columns]

# %%
df.to_csv('/Users/julienfestou/Desktop/Exports_BO/Reporting.csv')
